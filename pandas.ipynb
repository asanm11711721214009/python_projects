# %%
df=pd.read_csv('customer_shopping_behavior.csv')

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
import pandas as pd

# %%
df.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                     28    Virginia    L  Turquoise  Summer
# 3896                     49        Iowa    L      White  Spring
# 3897                     33  New Jersey    L      Green  Spring
# 3898                     77   Minnesota    S      Brown  Summer
# 3899                     81  California    M      Beige  Spring
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 3895            4.2                  No  2-Day Shipping               No
# 3896            4.5                  No    Store Pickup               No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3863.000000
# mean   1950.500000    44.068462              59.764359       3.750065
# std    1125.977353    15.207589              23.685392       0.716983
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.800000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
df.shape
# Out:
# (3900, 18)

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df['Review Rating']=df['Review Rating'].fillna(df['Review Rating'])

# %%
print(df)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df['Review Rating']=df['Review Rating'].fillna(df['Review Rating'].median())

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3895    False
# 3896    False
# 3897    False
# 3898    False
# 3899    False
# Length: 3900, dtype: bool

# %%
df=pd.Series([10,20,30,40,50,50])

# %%
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    50
# dtype: int64

# %%
df.dtype
# Out:
# dtype('int64')

# %%
food_menu=pd.Series(['dosa','idly','vadai'])

# %%
print(food_menu)
# Out:
# 0     dosa
# 1     idly
# 2    vadai
# dtype: object

# %%
food_price=pd.Series([100,25,45])

# %%
print(food_price)
# Out:
# 0    100
# 1     25
# 2     45
# dtype: int64

# %%
df1=pd.DataFrame({'food_menu':['dosa','idly','vadai']})

# %%
print(df1)
# Out:
#   food_menu
# 0      dosa
# 1      idly
# 2     vadai

# %%
df2=pd.DataFrame({'food_price':[24,56,78]})

# %%
print(df2)
# Out:
#    food_price
# 0          24
# 1          56
# 2          78

# %%
result=pd.concat([df1+df2],axis=1)

# %%
print(result)
# Out:
#   food_menu  food_price
# 0       NaN         NaN
# 1       NaN         NaN
# 2       NaN         NaN

# %%
food_type=pd.Series(['idly','vadai','dosa'])

# %%
food_price=pd.Series([24,56,78])

# %%
print(food_type)
# Out:
# 0     idly
# 1    vadai
# 2     dosa
# dtype: object

# %%
print(food_price)
# Out:
# 0    24
# 1    56
# 2    78
# dtype: int64

# %%
food_menu=pd.DataFrame({'food_type':food_type,'food_price':food_price})

# %%
food_menu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   food_type   3 non-null      object
#  1   food_price  3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
print(food_menu)
# Out:
#   food_type  food_price
# 0      idly          24
# 1     vadai          56
# 2      dosa          78

# %%
df.head()
# Out:
#   food_menu
# 0      dosa
# 1      idly
# 2     vadai

# %%
df.tail()
# Out:
#   food_menu
# 0      dosa
# 1      idly
# 2     vadai

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   food_menu  3 non-null      object
# dtypes: object(1)
# memory usage: 156.0+ bytes

# %%
df.describe()
# Out:
#        food_menu
# count          3
# unique         3
# top         dosa
# freq           1

# %%
df.shape
# Out:
# (3, 1)

# %%
food_menu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   food_type   3 non-null      object
#  1   food_price  3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
food_menu.describe()
# Out:
#        food_price
# count    3.000000
# mean    52.666667
# std     27.153882
# min     24.000000
# 25%     40.000000
# 50%     56.000000
# 75%     67.000000
# max     78.000000

# %%
food_menu.shape
# Out:
# (3, 2)

# %%
food_menu.isnull().sum()
# Out:
# food_type     0
# food_price    0
# dtype: int64

# %%
food_menu.columns
# Out:
# Index(['food_type', 'food_price'], dtype='object')

# %%
food_menu.rename
# Out:
# <bound method DataFrame.rename of   food_type  food_price
# 0      idly          24
# 1     vadai          56
# 2      dosa          78>

# %%
import pandas as pd

# %%
df=pd.read_excel('Emp Details XL.xlsx')
# Out:
# C:\Users\SATHYA\PycharmProjects\PythonProject\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Web Extension extension is not supported and will be removed
#   warn(msg)

# %%
df
# Out:
#     Emp ID              First Name      Dept             Desig  Gender  \
# 0      101        Rajaram Sundaram     sales   Sales Executive    Male
# 1      102  Abinaya Krishnamoorthy     sales   Sales Executive  Female
# 2      103      Naveen Chidambaram  accounts           Manager    Male
# 3      104     Shabeer Salman Khan  accounts  Junior Executive    Male
# 4      105  Sureshkumar Venkatesan     sales     Sales Manager    Male
# 5      106     Gayathri Srinivasan        IT         Developer  Female
# 6      107           Anu Rajagopal        IT           Testing  Female
# 7      108    Ashokumar Maheswaran        IT           Testing    Male
# 8      109          Charles Joseph     sales     Sales Manager    Male
# 9      110         Ashok Narayanan        IT         Developer    Male
# 10     111             Annie David  accounts           Manager  Female
# 11     112          Kavya Rajkumar     sales   Sales Executive  Female
#
# ...

# %%
df.groupby('Gender')['Salary'].sum()
# Out:
# Gender
# Female     89000
# Male      170000
# Name: Salary, dtype: int64

# %%
df.groupby('Gender')['Salary'].mean()
# Out:
# Gender
# Female    17800.000000
# Male      24285.714286
# Name: Salary, dtype: float64

# %%
df.groupby('Gender')['Salary'].max()
# Out:
# Gender
# Female    40000
# Male      45000
# Name: Salary, dtype: int64

# %%
df.groupby('Gender')['Salary'].min()
# Out:
# Gender
# Female    10000
# Male      10000
# Name: Salary, dtype: int64

# %%
df.groupby('Gender')['Emp ID'].count()
# Out:
# Gender
# Female    5
# Male      7
# Name: Emp ID, dtype: int64

# %%
df.groupby(['Gender','Dept'])['Emp ID'].count()
# Out:
# Gender  Dept
# Female  IT          2
#         accounts    1
#         sales       2
# Male    IT          2
#         accounts    2
#         sales       3
# Name: Emp ID, dtype: int64

# %%
df.groupby(['Gender','Dept','Desig'])['Salary'].agg(['sum','max','mean'])
# Out:
#                                     sum    max     mean
# Gender Dept     Desig
# Female IT       Developer         40000  40000  40000.0
#                 Testing           12000  12000  12000.0
#        accounts Manager           15000  15000  15000.0
#        sales    Sales Executive   22000  12000  11000.0
# Male   IT       Developer         45000  45000  45000.0
#                 Testing           12000  12000  12000.0
#        accounts Junior Executive  10000  10000  10000.0
#                 Manager           15000  15000  15000.0
#        sales    Sales Executive   12000  12000  12000.0
#                 Sales Manager     76000  38000  38000.0

# %%
df.groupby('Gender',as_index=False)['Salary'].sum().sort_values('Salary',ascending=False)
# Out:
#    Gender  Salary
# 1    Male  170000
# 0  Female   89000

# %%
df['Desig'].unique()
# Out:
# array(['Sales Executive', 'Manager', 'Junior Executive', 'Sales Manager',
#        'Developer', 'Testing'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Salary'].unique()
# Out:
# array([12000, 10000, 15000, 38000, 40000, 45000])

# %%
df['R Type'].unique()
# Out:
# array(['C', 'T', 'R', 'I'], dtype=object)

# %%
df.groupby('Gender')['Salary'].sum()
# Out:
# Gender
# Female     89000
# Male      170000
# Name: Salary, dtype: int64

# %%
df.columns
# Out:
# Index(['Emp ID', 'First Name', 'Dept', 'Desig', 'Gender', 'DoJoin', 'DoBirth',
#        'Salary', 'Location', 'R Type'],
#       dtype='object')
